# %% [markdown]
# # INTRODUCTION TO PANDAS

# %%
# Install pandas using pip
# !pip install pandas

# %% [markdown]
# # Key Data Structures in Pandas
# * Series (one dimentional)
# * DataFrame (two dimentional)

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 2.2.3

# %%
s = pd.Series([1, 2, 3, 4, 5], index=['a', 'b', 'c', 'd', 'e'])

# %%
s
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
df = pd.DataFrame({
    'A': [1, 2, 3],
    'B': [4, 5, 6],
    'C': [7, 8, 9]
})

# %%
df
# Out:
#    A  B  C
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9

# %%
df = pd.read_csv("office_employees.csv")

# %%
df
# Out:
#    employee_id                  name       department              position  \
# 0       EMP001           Gary Harper      Engineering    Frontend Developer
# 1       EMP002             Lee Walsh       IT Support  System Administrator
# 2       EMP003             John Soto  Human Resources          HR Executive
# 3       EMP004        Jennifer Foley          Finance     Financial Analyst
# 4       EMP005        Valerie Taylor        Marketing    Content Strategist
# 5       EMP006         Alan Phillips        Marketing  Social Media Manager
# 6       EMP007      Ashley Henderson  Human Resources          HR Executive
# 7       EMP008         Raymond Ellis          Finance     Financial Analyst
# 8       EMP009         William Baker        Marketing    Content Strategist
# 9       EMP010          Justin James            Sales       Sales Associate
# 10      EMP011      Nicholas Edwards            Sales       Sales Associate
# ...

# %%
df.head()
# Out:
#   employee_id            name       department              position  salary  \
# 0      EMP001     Gary Harper      Engineering    Frontend Developer   74889
# 1      EMP002       Lee Walsh       IT Support  System Administrator  115131
# 2      EMP003       John Soto  Human Resources          HR Executive  107183
# 3      EMP004  Jennifer Foley          Finance     Financial Analyst  116032
# 4      EMP005  Valerie Taylor        Marketing    Content Strategist   85420
#
#   date_joined                       email
# 0  2022-01-30     gary.harper@company.com
# 1  2022-01-02       lee.walsh@company.com
# 2  2019-07-08       john.soto@company.com
# 3  2024-11-21  jennifer.foley@company.com
# 4  2020-04-19  valerie.taylor@company.com

# %%
df.tail()
# Out:
#    employee_id                name       department            position  \
# 45      EMP046      Jennifer Baker            Sales   Account Executive
# 46      EMP047         Sean Fuller            Sales     Sales Associate
# 47      EMP048  Stephanie Townsend  Human Resources           Recruiter
# 48      EMP049        Grant Parker            Sales   Account Executive
# 49      EMP050       Susan Coleman        Marketing  Content Strategist
#
#     salary date_joined                           email
# 45   73902  2019-09-05      jennifer.baker@company.com
# 46   58420  2024-01-31         sean.fuller@company.com
# 47   95307  2019-08-24  stephanie.townsend@company.com
# 48   55554  2019-05-23        grant.parker@company.com
# 49   87292  2021-12-27       susan.coleman@company.com

# %%
df.describe()
# Out:
#               salary
# count      50.000000
# mean    86103.560000
# std     17309.596246
# min     55281.000000
# 25%     73710.500000
# 50%     84552.000000
# 75%    100158.750000
# max    117464.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   employee_id  50 non-null     object
#  1   name         50 non-null     object
#  2   department   50 non-null     object
#  3   position     50 non-null     object
#  4   salary       50 non-null     int64
#  5   date_joined  50 non-null     object
#  6   email        50 non-null     object
# dtypes: int64(1), object(6)
# memory usage: 2.9+ KB

# %% [markdown]
# # Data Selection

# %%
df.columns
# Out:
# Index(['employee_id', 'name', 'department', 'position', 'salary',
#        'date_joined', 'email'],
#       dtype='object')

# %%
df['name']
# Out:
# 0              Gary Harper
# 1                Lee Walsh
# 2                John Soto
# 3           Jennifer Foley
# 4           Valerie Taylor
# 5            Alan Phillips
# 6         Ashley Henderson
# 7            Raymond Ellis
# 8            William Baker
# 9             Justin James
# 10        Nicholas Edwards
# 11        Matthew Williams
# 12    Nathan Carpenter DDS
# 13          April Gonzalez
# 14              Cody Yoder
# 15          Jonathon Henry
# 16         Evelyn Bautista
# 17          Matthew Pierce
# 18          Makayla Orozco
# 19            Lindsay Diaz
# 20       Mr. Luis Williams
# 21            Kevin Mclean
# 22        Tyler Wilson DDS
# 23           Shannon Smith
# 24           Mark Gonzalez
# 25            Daniel Lewis
# 26          Stephanie Rose
# 27        Alyssa Rodriguez
# 28    Mrs. Teresa Lutz DVM
# 29         Cheryl Peterson
# 30           Laurie Murray
# 31            Sean Andrews
# 32         Anthony Sampson
# 33       Michael Maldonado
# ...

# %%
df[['name','email']]
# Out:
#                     name                             email
# 0            Gary Harper           gary.harper@company.com
# 1              Lee Walsh             lee.walsh@company.com
# 2              John Soto             john.soto@company.com
# 3         Jennifer Foley        jennifer.foley@company.com
# 4         Valerie Taylor        valerie.taylor@company.com
# 5          Alan Phillips         alan.phillips@company.com
# 6       Ashley Henderson      ashley.henderson@company.com
# 7          Raymond Ellis         raymond.ellis@company.com
# 8          William Baker         william.baker@company.com
# 9           Justin James          justin.james@company.com
# 10      Nicholas Edwards      nicholas.edwards@company.com
# 11      Matthew Williams      matthew.williams@company.com
# 12  Nathan Carpenter DDS  nathan.carpenter.dds@company.com
# 13        April Gonzalez        april.gonzalez@company.com
# 14            Cody Yoder            cody.yoder@company.com
# ...

# %%
df.iloc[0]
# Out:
# employee_id                     EMP001
# name                       Gary Harper
# department                 Engineering
# position            Frontend Developer
# salary                           74889
# date_joined                 2022-01-30
# email          gary.harper@company.com
# Name: 0, dtype: object

# %%
df2 = pd.read_csv('missing_office.csv')

# %%
df2.head()
# Out:
#   employee_id            name       department              position  \
# 0      EMP001     Gary Harper      Engineering    Frontend Developer
# 1      EMP002       Lee Walsh       IT Support  System Administrator
# 2      EMP003       John Soto  Human Resources                   NaN
# 3      EMP004  Jennifer Foley          Finance     Financial Analyst
# 4      EMP005  Valerie Taylor        Marketing    Content Strategist
#
#      salary date_joined                       email
# 0   74889.0  2022-01-30     gary.harper@company.com
# 1  115131.0  2022-01-02       lee.walsh@company.com
# 2  107183.0  2019-07-08       john.soto@company.com
# 3       NaN  2024-11-21  jennifer.foley@company.com
# 4   85420.0  2020-04-19  valerie.taylor@company.com

# %%
df2.dropna()
# Out:
#    employee_id                  name       department              position  \
# 0       EMP001           Gary Harper      Engineering    Frontend Developer
# 1       EMP002             Lee Walsh       IT Support  System Administrator
# 4       EMP005        Valerie Taylor        Marketing    Content Strategist
# 5       EMP006         Alan Phillips        Marketing  Social Media Manager
# 7       EMP008         Raymond Ellis          Finance     Financial Analyst
# 8       EMP009         William Baker        Marketing    Content Strategist
# 9       EMP010          Justin James            Sales       Sales Associate
# 10      EMP011      Nicholas Edwards            Sales       Sales Associate
# 12      EMP013  Nathan Carpenter DDS      Engineering       DevOps Engineer
# 13      EMP014        April Gonzalez      Engineering     Backend Developer
# 14      EMP015            Cody Yoder            Sales         Sales Manager
# ...

# %%
df2.fillna(0)
# df2.fillna(0, inplace=True) manupilates the orignal csv (not recommended)
# Out:
#    employee_id                  name       department              position  \
# 0       EMP001           Gary Harper      Engineering    Frontend Developer
# 1       EMP002             Lee Walsh       IT Support  System Administrator
# 2       EMP003             John Soto  Human Resources                     0
# 3       EMP004        Jennifer Foley          Finance     Financial Analyst
# 4       EMP005        Valerie Taylor        Marketing    Content Strategist
# 5       EMP006         Alan Phillips        Marketing  Social Media Manager
# 6       EMP007      Ashley Henderson                0          HR Executive
# 7       EMP008         Raymond Ellis          Finance     Financial Analyst
# 8       EMP009         William Baker        Marketing    Content Strategist
# 9       EMP010          Justin James            Sales       Sales Associate
# 10      EMP011      Nicholas Edwards            Sales       Sales Associate
# ...

# %%
df
# Out:
#    employee_id                  name       department              position  \
# 0       EMP001           Gary Harper      Engineering    Frontend Developer
# 1       EMP002             Lee Walsh       IT Support  System Administrator
# 2       EMP003             John Soto  Human Resources          HR Executive
# 3       EMP004        Jennifer Foley          Finance     Financial Analyst
# 4       EMP005        Valerie Taylor        Marketing    Content Strategist
# 5       EMP006         Alan Phillips        Marketing  Social Media Manager
# 6       EMP007      Ashley Henderson  Human Resources          HR Executive
# 7       EMP008         Raymond Ellis          Finance     Financial Analyst
# 8       EMP009         William Baker        Marketing    Content Strategist
# 9       EMP010          Justin James            Sales       Sales Associate
# 10      EMP011      Nicholas Edwards            Sales       Sales Associate
# ...

# %%
df.rename(columns={"employee_id": "e_id"})
# Out:
#       e_id                  name       department              position  \
# 0   EMP001           Gary Harper      Engineering    Frontend Developer
# 1   EMP002             Lee Walsh       IT Support  System Administrator
# 2   EMP003             John Soto  Human Resources          HR Executive
# 3   EMP004        Jennifer Foley          Finance     Financial Analyst
# 4   EMP005        Valerie Taylor        Marketing    Content Strategist
# 5   EMP006         Alan Phillips        Marketing  Social Media Manager
# 6   EMP007      Ashley Henderson  Human Resources          HR Executive
# 7   EMP008         Raymond Ellis          Finance     Financial Analyst
# 8   EMP009         William Baker        Marketing    Content Strategist
# 9   EMP010          Justin James            Sales       Sales Associate
# 10  EMP011      Nicholas Edwards            Sales       Sales Associate
# 11  EMP012      Matthew Williams       IT Support  System Administrator
# ...

# %%
# permanantly rename the column
df.rename(columns={"employee_id": "e_id"}, inplace=True)

# %%
df
# Out:
#       e_id                  name       department              position  \
# 0   EMP001           Gary Harper      Engineering    Frontend Developer
# 1   EMP002             Lee Walsh       IT Support  System Administrator
# 2   EMP003             John Soto  Human Resources          HR Executive
# 3   EMP004        Jennifer Foley          Finance     Financial Analyst
# 4   EMP005        Valerie Taylor        Marketing    Content Strategist
# 5   EMP006         Alan Phillips        Marketing  Social Media Manager
# 6   EMP007      Ashley Henderson  Human Resources          HR Executive
# 7   EMP008         Raymond Ellis          Finance     Financial Analyst
# 8   EMP009         William Baker        Marketing    Content Strategist
# 9   EMP010          Justin James            Sales       Sales Associate
# 10  EMP011      Nicholas Edwards            Sales       Sales Associate
# 11  EMP012      Matthew Williams       IT Support  System Administrator
# ...

# %%
df.describe()
# Out:
#               salary
# count      50.000000
# mean    86103.560000
# std     17309.596246
# min     55281.000000
# 25%     73710.500000
# 50%     84552.000000
# 75%    100158.750000
# max    117464.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   e_id         50 non-null     object
#  1   name         50 non-null     object
#  2   department   50 non-null     object
#  3   position     50 non-null     object
#  4   salary       50 non-null     int64
#  5   date_joined  50 non-null     object
#  6   email        50 non-null     object
# dtypes: int64(1), object(6)
# memory usage: 2.9+ KB

# %%
# change the data type of a column
df['salary'] = df['salary'].astype(int)
df['salary'].dtype
# Out:
# dtype('int64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   e_id         50 non-null     object
#  1   name         50 non-null     object
#  2   department   50 non-null     object
#  3   position     50 non-null     object
#  4   salary       50 non-null     int64
#  5   date_joined  50 non-null     object
#  6   email        50 non-null     object
# dtypes: int64(1), object(6)
# memory usage: 2.9+ KB

# %%
df['e_id'] = df['e_id'].astype("string")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   e_id         50 non-null     string
#  1   name         50 non-null     object
#  2   department   50 non-null     object
#  3   position     50 non-null     object
#  4   salary       50 non-null     int64
#  5   date_joined  50 non-null     object
#  6   email        50 non-null     object
# dtypes: int64(1), object(5), string(1)
# memory usage: 2.9+ KB

# %%
df['zeros'] = [0 for i in range (len(df))]

# %%
df
# Out:
#       e_id                  name       department              position  \
# 0   EMP001           Gary Harper      Engineering    Frontend Developer
# 1   EMP002             Lee Walsh       IT Support  System Administrator
# 2   EMP003             John Soto  Human Resources          HR Executive
# 3   EMP004        Jennifer Foley          Finance     Financial Analyst
# 4   EMP005        Valerie Taylor        Marketing    Content Strategist
# 5   EMP006         Alan Phillips        Marketing  Social Media Manager
# 6   EMP007      Ashley Henderson  Human Resources          HR Executive
# 7   EMP008         Raymond Ellis          Finance     Financial Analyst
# 8   EMP009         William Baker        Marketing    Content Strategist
# 9   EMP010          Justin James            Sales       Sales Associate
# 10  EMP011      Nicholas Edwards            Sales       Sales Associate
# 11  EMP012      Matthew Williams       IT Support  System Administrator
# ...

# %%
def fx(a):
    return a + 1
df['zeros + 1'] = df['zeros'].apply(fx)

# %%
df
# Out:
#       e_id                  name       department              position  \
# 0   EMP001           Gary Harper      Engineering    Frontend Developer
# 1   EMP002             Lee Walsh       IT Support  System Administrator
# 2   EMP003             John Soto  Human Resources          HR Executive
# 3   EMP004        Jennifer Foley          Finance     Financial Analyst
# 4   EMP005        Valerie Taylor        Marketing    Content Strategist
# 5   EMP006         Alan Phillips        Marketing  Social Media Manager
# 6   EMP007      Ashley Henderson  Human Resources          HR Executive
# 7   EMP008         Raymond Ellis          Finance     Financial Analyst
# 8   EMP009         William Baker        Marketing    Content Strategist
# 9   EMP010          Justin James            Sales       Sales Associate
# 10  EMP011      Nicholas Edwards            Sales       Sales Associate
# 11  EMP012      Matthew Williams       IT Support  System Administrator
# ...

# %%
def fy(b):
    return b*2
df['double_sal'] = df['salary'].apply(fy)

# %%
df
# Out:
#       e_id                  name       department              position  \
# 0   EMP001           Gary Harper      Engineering    Frontend Developer
# 1   EMP002             Lee Walsh       IT Support  System Administrator
# 2   EMP003             John Soto  Human Resources          HR Executive
# 3   EMP004        Jennifer Foley          Finance     Financial Analyst
# 4   EMP005        Valerie Taylor        Marketing    Content Strategist
# 5   EMP006         Alan Phillips        Marketing  Social Media Manager
# 6   EMP007      Ashley Henderson  Human Resources          HR Executive
# 7   EMP008         Raymond Ellis          Finance     Financial Analyst
# 8   EMP009         William Baker        Marketing    Content Strategist
# 9   EMP010          Justin James            Sales       Sales Associate
# 10  EMP011      Nicholas Edwards            Sales       Sales Associate
# 11  EMP012      Matthew Williams       IT Support  System Administrator
# ...

# %%
df.to_csv('modified.csv', index=False)

# %% [markdown]
# # ___________________________________________

# %%
dfalpha = pd.DataFrame({
    'name' : ['mojez','zehra','huma'],
    'marks' : [100,95,99],
})
dfalpha
# Out:
#     name  marks
# 0  mojez    100
# 1  zehra     95
# 2   huma     99

# %%
dfbeta = pd.DataFrame({
    'name' : ['mojez','huma'],
    'roll' :[1244,1255],
})
dfbeta
# Out:
#     name  roll
# 0  mojez  1244
# 1   huma  1255

# %%
pd.merge(dfalpha,dfbeta ,on='name')
# Out:
#     name  marks  roll
# 0  mojez    100  1244
# 1   huma     99  1255

# %%
pd.concat([dfalpha,dfbeta])
# Out:
#     name  marks    roll
# 0  mojez  100.0     NaN
# 1  zehra   95.0     NaN
# 2   huma   99.0     NaN
# 0  mojez    NaN  1244.0
# 1   huma    NaN  1255.0
